# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"C:\Users\HP\Desktop\PW_Projects\Body_Mass_Index_from_Face_Images\notebooks\BMI_Data_Analysis_and_Modelling\final_bmi_dataset.csv")

# %%
data.head()
# Out:
#            FL        FRHL         ETL         MEL         BEL      LIPL_L  \
# 0  506.675439  380.788655  456.207190  451.486434  443.180550  415.896622
# 1  745.603782  540.267526  646.650601  651.229606  622.874787  584.931620
# 2  674.086790  458.661095  532.580510  524.764709  505.213816  471.021231
# 3  669.431102  424.835262  514.557091  463.400475  507.252403  480.037499
# 4  780.185875  551.272165  641.510717  667.083203  606.399208  568.148748
#
#            JL         FLL         FLR     DFL_L_R  ...         NWL  \
# 0  325.227613  435.986238  437.370552  486.050409  ...   95.634722
# 1  457.856965  641.201996  627.179400  690.525162  ...  140.128512
# 2  368.543078  562.090740  573.007853  614.239367  ...  132.306462
# 3  378.107128  540.948242  592.420459  649.683769  ...  113.110565
# 4  440.010227  691.011577  646.320354  674.206200  ...  135.059246
#
#           L_L         L_W         LEL        LEW         REL        REW  \
# 0  204.298801   41.194660   91.662424  39.560081   99.984999  41.109610
# 1  304.420761   77.006493  140.288987  62.513998  139.032370  58.309519
# 2  295.611231  100.498756  117.153745  72.780492  132.849539  73.109507
# 3  259.277843   95.126232   81.154174  56.612719  142.506140  58.008620
# 4  293.061427   84.852814  162.996932  85.052925  124.016128  80.808415
#
#             FA  Gender        BMI
# 0   15826398.5       1  21.920815
# 1  104703027.0       1  21.116857
# 2  106843369.0       1  20.378209
# 3  154144551.5       1  21.287767
# 4  181100490.0       0  20.883184
#
# [5 rows x 21 columns]

# %% [markdown]
# * FL                                          ## Face Lenght
# * FRHL                                        ## Fore Head Length
# * ETL                                         ## Ear Tip Length
# * MEL                                         ## Mid Ear Length
# * BEL                                         ## Bottom Ear Length
# * LIPL_L                                      ## LIP Line Length
# * JL                                          ## Jaw Length
# * FLL                                         ## Face Length Left
# * FLR                                         ## Face Length Right
# * DFL_L_R                                     ## Diagonal Face Length Left to Right
# * DFL_R_L                                     ## Diagonal Face Length Right to Left
# * NWL                                         ## Nose Width Length
# * L_L                                         ## Lip Length
# * L_W                                         ## Lip Width
# * LEL                                         ## Left Eye Length
# * LEW                                         ## LEft Eye Width
# * REL                                         ## Right Eye Length
# * REW                                         ## Right Eye Width
# * FA                                          ## Facial Area

# %%
data.shape
# Out:
# (976, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 976 entries, 0 to 975
# Data columns (total 21 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   FL       976 non-null    float64
#  1   FRHL     976 non-null    float64
#  2   ETL      976 non-null    float64
#  3   MEL      976 non-null    float64
#  4   BEL      976 non-null    float64
#  5   LIPL_L   976 non-null    float64
#  6   JL       976 non-null    float64
#  7   FLL      976 non-null    float64
#  8   FLR      976 non-null    float64
#  9   DFL_L_R  976 non-null    float64
#  10  DFL_R_L  976 non-null    float64
#  11  NWL      976 non-null    float64
#  12  L_L      976 non-null    float64
#  13  L_W      976 non-null    float64
#  14  LEL      976 non-null    float64
#  15  LEW      976 non-null    float64
#  16  REL      976 non-null    float64
#  17  REW      976 non-null    float64
#  18  FA       976 non-null    float64
#  19  Gender   976 non-null    int64
#  20  BMI      976 non-null    float64
# dtypes: float64(20), int64(1)
# memory usage: 160.2 KB

# %%
data.isnull().sum()
# Out:
# FL         0
# FRHL       0
# ETL        0
# MEL        0
# BEL        0
# LIPL_L     0
# JL         0
# FLL        0
# FLR        0
# DFL_L_R    0
# DFL_R_L    0
# NWL        0
# L_L        0
# L_W        0
# LEL        0
# LEW        0
# REL        0
# REW        0
# FA         0
# Gender     0
# BMI        0
# dtype: int64

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [FL, FRHL, ETL, MEL, BEL, LIPL_L, JL, FLL, FLR, DFL_L_R, DFL_R_L, NWL, L_L, L_W, LEL, LEW, REL, REW, FA, Gender, BMI]
# Index: []
#
# [0 rows x 21 columns]

# %%
data.describe()
# Out:
#                 FL         FRHL          ETL          MEL          BEL  \
# count   976.000000   976.000000   976.000000   976.000000   976.000000
# mean    659.048298   472.049886   557.548230   552.074974   536.340555
# std     218.741292   155.566286   184.349573   184.065366   178.517896
# min     216.171228   145.134420   176.589920   165.737745   171.268795
# 25%     511.758732   366.132485   432.285777   427.109177   415.376925
# 50%     561.470390   405.611881   479.557609   472.138603   460.696753
# 75%     821.427110   584.785827   697.774133   690.532561   667.663202
# max    1697.106361  1267.006314  1461.027720  1431.478257  1363.052824
#
#             LIPL_L          JL          FLL          FLR      DFL_L_R  ...  \
# count   976.000000  976.000000   976.000000   976.000000   976.000000  ...
# mean    503.208224  395.543143   558.881673   558.675535   610.988632  ...
# std     167.879423  132.533101   186.478671   185.456937   202.443769  ...
# min     159.878079  127.675370   178.025279   182.649938   197.284059  ...
# 25%     389.987819  305.163475   432.247903   431.878741   471.031842  ...
# 50%     433.127568  340.002204   476.021533   477.883852   527.202997  ...
# 75%     628.109970  491.275111   702.416505   702.373027   763.582345  ...
# max    1269.066586  993.050351  1421.186124  1431.670353  1536.391877  ...
#
#               NWL         L_L         L_W         LEL         LEW         REL  \
# count  976.000000  976.000000  976.000000  976.000000  976.000000  976.000000
# mean   125.260082  270.977304   73.000763  118.051961   58.194308  126.369724
# std     41.858798   90.386302   32.529250   40.389754   19.922321   42.772843
# min     38.639358   81.024688   19.000000   31.400637   18.439089   40.112342
# 25%     97.020616  208.278058   49.145183   90.184529   43.723556   97.005155
# 50%    108.261253  236.077311   65.867211  102.506062   51.307875  110.643572
# 75%    154.031645  333.062675   88.009942  147.471854   72.221832  152.630259
# max    325.055380  681.143891  244.008197  303.595125  134.736780  343.313268
#
#               REW            FA      Gender         BMI
# count  976.000000  9.760000e+02  976.000000  976.000000
# mean    57.876285  5.814735e+07    0.932377   21.161385
# std     19.870415  5.158248e+07    0.251226    1.959828
# min     17.262677  5.188170e+05    0.000000    6.390763
# 25%     43.634830  2.284586e+07    1.000000   20.378209
# 50%     51.122391  3.165886e+07    1.000000   21.614131
# 75%     71.499981  8.838685e+07    1.000000   22.346227
# max    140.246212  2.896861e+08    1.000000   25.239265
#
# [8 rows x 21 columns]

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
num_columns = len(data.columns)
fig, axes = plt.subplots(nrows=7, ncols=3, figsize=(15, 20)) 
axes = axes.flatten()
for i in range(num_columns):
    sns.histplot(data[data.columns[i]], kde=True, ax=axes[i], color='skyblue')  
    axes[i].set_title(data.columns[i])
plt.tight_layout()
plt.show()

# %%
num_columns = len(data.columns)
fig, axes = plt.subplots(nrows=7, ncols=3, figsize=(15, 20)) 
axes = axes.flatten()
for i in range(num_columns):
    sns.boxplot(data[data.columns[i]], ax=axes[i], color='skyblue')  
    axes[i].set_title(data.columns[i])
plt.tight_layout()
plt.show()

# %%
category = []
for bmi in data['BMI']:
    if bmi < 18.5:
       category.append('Malnourished')
    elif bmi > 24:
        category.append('Overweight')
    else:
        category.append('Normal')

# %%
data["BMI_category"] = category

# %%
data
# Out:
#              FL        FRHL         ETL         MEL         BEL      LIPL_L  \
# 0    506.675439  380.788655  456.207190  451.486434  443.180550  415.896622
# 1    745.603782  540.267526  646.650601  651.229606  622.874787  584.931620
# 2    674.086790  458.661095  532.580510  524.764709  505.213816  471.021231
# 3    669.431102  424.835262  514.557091  463.400475  507.252403  480.037499
# 4    780.185875  551.272165  641.510717  667.083203  606.399208  568.148748
# ..          ...         ...         ...         ...         ...         ...
# 971  486.124470  340.013235  403.060789  385.063631  388.217722  364.269131
# 972  558.227552  388.363232  469.886156  487.643312  463.815696  438.320659
# 973  548.292805  442.574288  505.715335  495.663192  466.734400  432.209440
# 974  887.608585  626.419189  724.199558  729.561512  698.719543  657.735509
# 975  625.843431  450.639546  536.016791  526.744720  521.176554  489.182992
#
#              JL         FLL         FLR     DFL_L_R  ...         L_L  \
# 0    325.227613  435.986238  437.370552  486.050409  ...  204.298801
# 1    457.856965  641.201996  627.179400  690.525162  ...  304.420761
# 2    368.543078  562.090740  573.007853  614.239367  ...  295.611231
# 3    378.107128  540.948242  592.420459  649.683769  ...  259.277843
# 4    440.010227  691.011577  646.320354  674.206200  ...  293.061427
# ..          ...         ...         ...         ...  ...         ...
# 971  285.343652  405.356633  418.303717  456.150195  ...  192.127562
# 972  345.522792  497.197144  468.124983  518.973024  ...  220.818930
# 973  332.746149  466.366808  467.723209  532.504460  ...  236.408545
# 974  521.463326  753.634527  739.010825  786.649859  ...  356.033706
# 975  385.093495  533.093800  543.656141  593.667415  ...  246.519776
#
#             L_W         LEL        LEW         REL        REW           FA  \
# 0     41.194660   91.662424  39.560081   99.984999  41.109610   15826398.5
# 1     77.006493  140.288987  62.513998  139.032370  58.309519  104703027.0
# 2    100.498756  117.153745  72.780492  132.849539  73.109507  106843369.0
# 3     95.126232   81.154174  56.612719  142.506140  58.008620  154144551.5
# 4     84.852814  162.996932  85.052925  124.016128  80.808415  181100490.0
# ..          ...         ...        ...         ...        ...          ...
# 971   47.095647   78.000000  39.812058   98.020406  39.623226   23552490.0
# 972   37.483330  107.466274  50.000000   89.805345  46.097722   28284211.0
# 973   56.089215  110.548632  57.870545  121.753850  57.008771    8974624.5
# 974   86.052310  161.697248  64.031242  163.229899  63.639610   64078829.0
# 975   64.124878  108.166538  51.156622  122.065556  51.971146  116676545.5
#
#      Gender        BMI  BMI_category
# 0         1  21.920815        Normal
# 1         1  21.116857        Normal
# 2         1  20.378209        Normal
# 3         1  21.287767        Normal
# 4         0  20.883184        Normal
# ..      ...        ...           ...
# 971       1  20.178999        Normal
# 972       1  20.178999        Normal
# 973       0  17.591365  Malnourished
# 974       1  22.208872        Normal
# 975       1  20.940600        Normal
#
# [976 rows x 22 columns]

# %%
data['BMI_category'].value_counts()
# Out:
# BMI_category
# Normal          878
# Malnourished     80
# Overweight       18
# Name: count, dtype: int64

# %%
data[data['BMI_category'] == 'Overweight']
# Out:
#               FL        FRHL          ETL          MEL          BEL  \
# 50    615.003252  431.375706   515.190256   532.000000   507.035502
# 118  1083.668307  723.747193   858.618076   827.635789   814.791384
# 119  1027.017527  718.712738   885.578342   883.839918   892.378843
# 144   819.425408  594.932769   697.717708   709.233389   669.352672
# 261   492.009146  377.000000   454.004405   448.004464   442.018099
# 284   391.471583  255.986328   304.029604   283.007067   291.295383
# 295   446.060534  349.413795   404.079200   416.030047   388.001289
# 377  1108.648276  781.918794   922.323696   959.713499   912.066335
# 553   604.497312  405.571202   482.722488   495.706566   474.455477
# 573   408.647770  312.129781   364.067301   354.001412   344.023255
# 637   939.579693  615.182087   738.530974   690.428852   742.695765
# 644  1025.597387  666.348257   795.342693   764.589432   765.300595
# 696  1270.106295  906.118094  1080.400852  1067.125578  1038.353504
# 795  1176.010629  757.634477   897.376732   871.449941   882.127542
# 883  1032.630137  690.959478   818.753321   863.945021   794.230445
# 902  1047.240183  763.755196   916.037663   878.601730   906.564945
# 924   958.718415  735.631022   870.775516   879.632310   867.163191
# 968   284.613773  211.009478   251.771722   252.833938   244.049175
#
#          LIPL_L          JL          FLL          FLR      DFL_L_R  ...  \
# 50   477.004193  384.032551   526.243290   501.527666   562.944047  ...
# 118  749.413104  585.669702   884.732728   908.035242   961.339170  ...
# 119  841.287703  686.104948   834.216399   852.005282   970.765162  ...
# 144  621.843228  491.883116   707.248895   676.026627   719.180784  ...
# 261  416.019230  325.024614   422.739873   426.985948   487.824764  ...
# 284  269.519944  212.256920   311.977563   341.021993   370.552291  ...
# 295  365.005479  295.006780   377.927242   352.547869   456.074555  ...
# 377  865.087857  701.082734   962.331024   913.731361  1015.291091  ...
# 553  445.533388  355.820179   506.451380   488.205899   530.947267  ...
# 573  320.014062  250.000000   346.482323   352.090897   395.284708  ...
# 637  705.555809  574.067940   765.836144   824.924239   906.739213  ...
# 644  716.774023  559.654358   860.035464   883.579651   916.372195  ...
# 696  972.286480  760.106571  1056.295887  1058.626469  1166.055316  ...
# 795  831.060166  663.003017   991.115029  1019.708292  1054.381809  ...
# 883  744.587134  581.309728   920.662805   854.028688   848.232280  ...
# 902  861.965777  692.870118   862.360134   900.035555  1043.398294  ...
# 924  823.894411  670.020895   819.349132   803.840780   941.563062  ...
# 968  229.512527  181.033146   248.243832   242.167298   272.662795  ...
#
#             L_L         L_W         LEL         LEW         REL         REW  \
# 50   260.030767   97.329338  123.000000   60.299254  106.117859   60.406953
# 118  359.556671  241.197015  172.290452  103.812331  203.194488  108.115679
# 119  479.204549  230.054341  179.627392   88.119237  205.000000   89.453899
# 144  293.874123  129.096863  162.151164   88.526832  143.610585   87.367042
# 261  209.038274   42.011903   91.005494   40.311289  101.044545   41.194660
# 284  160.561515   97.082439   55.081757   46.173586   86.683332   49.040799
# 295  245.008163  108.074049  103.043680   44.384682   88.277970   39.115214
# 377  487.344847  128.097619  224.510579  115.069544  192.629177  115.446958
# 553  270.601183  120.220631  115.260574   56.035703  106.301458   52.810984
# 573  162.012345   42.190046   74.108029   37.643060   83.600239   36.878178
# 637  350.851821  123.975804  127.011810   79.378838  203.531324   86.052310
# 644  360.606434  110.476242  152.210381   85.440037  192.675894   88.362888
# 696  559.915172  208.060087  225.641308  102.591423  242.018594  101.138519
# 795  419.042957  115.156415  174.071824   91.678787  214.336185   97.493590
# 883  345.305662  114.284732  206.196508  109.224539  140.128512  101.237345
# 902  472.002119  113.758516  173.769963   88.022724  228.254244   84.023806
# 924  416.390442   79.630396  190.947637   94.085068  193.662077   92.892411
# 968  113.564959   23.537205   54.571055   27.166155   52.172790   25.632011
#
#               FA  Gender        BMI  BMI_category
# 50   109534479.5       1  24.941979    Overweight
# 118   90922036.0       1  24.256673    Overweight
# 119  115955680.0       1  24.639564    Overweight
# 144   93443166.0       1  24.030982    Overweight
# 261   26988057.5       1  24.108926    Overweight
# 284   43145331.0       1  24.695227    Overweight
# 295   52025693.5       1  24.256673    Overweight
# 377  164125153.0       1  24.030982    Overweight
# 553   62394126.5       1  24.896664    Overweight
# 573   43917471.0       1  24.394021    Overweight
# 637  203392057.5       1  25.239265    Overweight
# 644  101720359.5       1  24.184133    Overweight
# 696   74094541.0       1  24.326614    Overweight
# 795   73400198.5       1  24.521487    Overweight
# 883  148197266.5       1  24.941979    Overweight
# 902    7541262.0       1  24.030982    Overweight
# 924  172921833.0       1  24.108926    Overweight
# 968   26763206.0       1  24.326614    Overweight
#
# [18 rows x 22 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data['BMI_category'] = encoder.fit_transform(data['BMI_category'])

# %%
data
# Out:
#              FL        FRHL         ETL         MEL         BEL      LIPL_L  \
# 0    506.675439  380.788655  456.207190  451.486434  443.180550  415.896622
# 1    745.603782  540.267526  646.650601  651.229606  622.874787  584.931620
# 2    674.086790  458.661095  532.580510  524.764709  505.213816  471.021231
# 3    669.431102  424.835262  514.557091  463.400475  507.252403  480.037499
# 4    780.185875  551.272165  641.510717  667.083203  606.399208  568.148748
# ..          ...         ...         ...         ...         ...         ...
# 971  486.124470  340.013235  403.060789  385.063631  388.217722  364.269131
# 972  558.227552  388.363232  469.886156  487.643312  463.815696  438.320659
# 973  548.292805  442.574288  505.715335  495.663192  466.734400  432.209440
# 974  887.608585  626.419189  724.199558  729.561512  698.719543  657.735509
# 975  625.843431  450.639546  536.016791  526.744720  521.176554  489.182992
#
#              JL         FLL         FLR     DFL_L_R  ...         L_L  \
# 0    325.227613  435.986238  437.370552  486.050409  ...  204.298801
# 1    457.856965  641.201996  627.179400  690.525162  ...  304.420761
# 2    368.543078  562.090740  573.007853  614.239367  ...  295.611231
# 3    378.107128  540.948242  592.420459  649.683769  ...  259.277843
# 4    440.010227  691.011577  646.320354  674.206200  ...  293.061427
# ..          ...         ...         ...         ...  ...         ...
# 971  285.343652  405.356633  418.303717  456.150195  ...  192.127562
# 972  345.522792  497.197144  468.124983  518.973024  ...  220.818930
# 973  332.746149  466.366808  467.723209  532.504460  ...  236.408545
# 974  521.463326  753.634527  739.010825  786.649859  ...  356.033706
# 975  385.093495  533.093800  543.656141  593.667415  ...  246.519776
#
#             L_W         LEL        LEW         REL        REW           FA  \
# 0     41.194660   91.662424  39.560081   99.984999  41.109610   15826398.5
# 1     77.006493  140.288987  62.513998  139.032370  58.309519  104703027.0
# 2    100.498756  117.153745  72.780492  132.849539  73.109507  106843369.0
# 3     95.126232   81.154174  56.612719  142.506140  58.008620  154144551.5
# 4     84.852814  162.996932  85.052925  124.016128  80.808415  181100490.0
# ..          ...         ...        ...         ...        ...          ...
# 971   47.095647   78.000000  39.812058   98.020406  39.623226   23552490.0
# 972   37.483330  107.466274  50.000000   89.805345  46.097722   28284211.0
# 973   56.089215  110.548632  57.870545  121.753850  57.008771    8974624.5
# 974   86.052310  161.697248  64.031242  163.229899  63.639610   64078829.0
# 975   64.124878  108.166538  51.156622  122.065556  51.971146  116676545.5
#
#      Gender        BMI  BMI_category
# 0         1  21.920815             1
# 1         1  21.116857             1
# 2         1  20.378209             1
# 3         1  21.287767             1
# 4         0  20.883184             1
# ..      ...        ...           ...
# 971       1  20.178999             1
# 972       1  20.178999             1
# 973       0  17.591365             0
# 974       1  22.208872             1
# 975       1  20.940600             1
#
# [976 rows x 22 columns]

# %%
X = data.drop(columns='BMI_category')
y = data['BMI_category']

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X,y)

# %%
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.Series(y_resampled, name=y.name)

# %%
df = pd.concat([X_resampled_df,y_resampled_df],axis=1)

# %%
df = df.drop(columns="BMI_category")

# %%
df
# Out:
#                FL        FRHL         ETL         MEL         BEL      LIPL_L  \
# 0      506.675439  380.788655  456.207190  451.486434  443.180550  415.896622
# 1      745.603782  540.267526  646.650601  651.229606  622.874787  584.931620
# 2      674.086790  458.661095  532.580510  524.764709  505.213816  471.021231
# 3      669.431102  424.835262  514.557091  463.400475  507.252403  480.037499
# 4      780.185875  551.272165  641.510717  667.083203  606.399208  568.148748
# ...           ...         ...         ...         ...         ...         ...
# 2629  1040.414454  719.903300  879.202707  870.548616  874.030755  819.560954
# 2630   362.327842  273.208546  327.551255  325.967178  318.231016  299.399307
# 2631   392.275709  257.362568  305.503392  284.966572  292.719916  270.926500
# 2632  1081.480950  714.502739  844.447720  828.446817  825.721558  775.597380
# 2633  1049.099132  710.665413  841.191387  884.692841  819.759072  770.693085
#
#               JL         FLL         FLR     DFL_L_R  ...         NWL  \
# 0     325.227613  435.986238  437.370552  486.050409  ...   95.634722
# 1     457.856965  641.201996  627.179400  690.525162  ...  140.128512
# 2     368.543078  562.090740  573.007853  614.239367  ...  132.306462
# 3     378.107128  540.948242  592.420459  649.683769  ...  113.110565
# 4     440.010227  691.011577  646.320354  674.206200  ...  135.059246
# ...          ...         ...         ...         ...  ...         ...
# 2629  662.353754  846.162635  865.255396  968.536078  ...  203.973986
# 2630  234.988848  313.630041  311.421539  353.287120  ...   67.985584
# 2631  213.475872  312.949040  341.191776  371.812082  ...   72.462045
# 2632  617.639641  915.862963  928.599307  965.521017  ...  196.361569
# 2633  607.258023  929.690041  866.963009  884.424836  ...  186.988104
#
#              L_L         L_W         LEL         LEW         REL         REW  \
# 0     204.298801   41.194660   91.662424   39.560081   99.984999   41.109610
# 1     304.420761   77.006493  140.288987   62.513998  139.032370   58.309519
# 2     295.611231  100.498756  117.153745   72.780492  132.849539   73.109507
# 3     259.277843   95.126232   81.154174   56.612719  142.506140   58.008620
# 4     293.061427   84.852814  162.996932   85.052925  124.016128   80.808415
# ...          ...         ...         ...         ...         ...         ...
# 2629  450.909901  232.689390  177.892333   91.830382  204.573028   93.867086
# 2630  149.340202   30.459943   68.223570   32.091828   70.485749   31.463562
# 2631  161.805462   97.244352   55.788264   46.147234   86.706822   48.894590
# 2632  385.861072  118.851986  170.911693   90.843213  195.587039   94.809072
# 2633  376.077826  117.277233  210.164171  110.490834  151.502551  104.315795
#
#                 FA  Gender        BMI
# 0     1.582640e+07       1  21.920815
# 1     1.047030e+08       1  21.116857
# 2     1.068434e+08       1  20.378209
# 3     1.541446e+08       1  21.287767
# 4     1.811005e+08       0  20.883184
# ...            ...     ...        ...
# 2629  1.100357e+08       1  24.549017
# 2630  2.684746e+07       1  24.245043
# 2631  4.327614e+07       1  24.688767
# 2632  7.871353e+07       1  24.391456
# 2633  1.516480e+08       1  24.744616
#
# [2634 rows x 21 columns]

# %%
num_columns = len(df.columns)
fig, axes = plt.subplots(nrows=7, ncols=3, figsize=(15, 20)) 
axes = axes.flatten()
for i in range(num_columns):
    sns.histplot(df[df.columns[i]], kde=True, ax=axes[i], color='skyblue')  
    axes[i].set_title(df.columns[i])
plt.tight_layout()
plt.show()

# %%
X = df.drop(columns = "BMI")
y = df['BMI']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
Standard_Scaler = StandardScaler()
X_train_Standard_Scaler = Standard_Scaler.fit_transform(X_train)
X_test_Standard_Scaler = Standard_Scaler.transform(X_test)

# %%
from sklearn.preprocessing import MinMaxScaler
Min_Max_Scaler = MinMaxScaler()
X_train_Min_Max_Scaler = Min_Max_Scaler.fit_transform(X_train)
X_test_Min_Max_Scaler = Min_Max_Scaler.transform(X_test)

# %%
from sklearn.preprocessing import RobustScaler
Robust_Scaler = RobustScaler()
X_train_Robust_Scaler = Robust_Scaler.fit_transform(X_train)
X_test_Robust_Scaler = Robust_Scaler.transform(X_test)

# %%
from sklearn.preprocessing import MaxAbsScaler
MaxAbs_Scaler = MaxAbsScaler()
X_train_MaxAbs_Scaler = MaxAbs_Scaler.fit_transform(X_train)
X_test_MaxAbs_Scaler = MaxAbs_Scaler.transform(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
def metrics(y_actual,y_predicted):
    MAE = mean_absolute_error(y_actual,y_predicted)
    MSE = mean_squared_error(y_actual,y_predicted)
    RMSE = (MSE**0.5)
    r2 = r2_score(y_actual,y_predicted)
    return MAE,MSE,RMSE,r2

# %%
X_data = {"X_without_scaling":[X_train,X_test],
          "X_Min_Max_Scaler":[X_train_Min_Max_Scaler,X_test_Min_Max_Scaler],
          "X_Standard_Scaler":[X_train_Standard_Scaler,X_test_Standard_Scaler],
          "X_Robust_Scaler":[X_train_Robust_Scaler,X_test_Robust_Scaler],
          "X_MaxAbs_Scaler":[X_train_MaxAbs_Scaler,X_test_MaxAbs_Scaler]}

# %%
from sklearn.linear_model import LinearRegression
def Simple_Linear_Regression():
    Linear_Regression = LinearRegression()
    for key,value in X_data.items():
        print(f'Working with: {key}')
        print("--------------------------------------------------------------------------------------------------------------------------------------------------")
        Linear_Regression.fit(value[0],y_train)
        print(f'Done with fitting the data using: {key}')
        print(f'Prediction started with: {key}')
        y_predicted = Linear_Regression.predict(value[1])
        print(f'Prediction completed with: {key}')
        print(f"Calculating metrics for {key}")
        MAE,MSE,RMSE,r2 = metrics(y_test,y_predicted)
        print(f"The Mean absolute error using data with, {key[2:]} is {MAE}")
        print(f"The Mean squared error using data with, {key[2:]} is {MSE}")
        print(f"The Root Mean squared error using data with, {key[2:]} is {RMSE}")
        print(f"The R2_sqaure using data with, {key[2:]} is {r2}")
        print("==================================================================================================================================================")
Simple_Linear_Regression()
# Out:
# Working with: X_without_scaling
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_without_scaling
# Prediction started with: X_without_scaling
# Prediction completed with: X_without_scaling
# Calculating metrics for X_without_scaling
# The Mean absolute error using data with, without_scaling is 1.4455187754123027
# The Mean squared error using data with, without_scaling is 3.8786240482909893
# The Root Mean squared error using data with, without_scaling is 1.9694222625661033
# The R2_sqaure using data with, without_scaling is 0.6920550538986141
# ==================================================================================================================================================
# Working with: X_Min_Max_Scaler
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_Min_Max_Scaler
# Prediction started with: X_Min_Max_Scaler
# Prediction completed with: X_Min_Max_Scaler
# Calculating metrics for X_Min_Max_Scaler
# The Mean absolute error using data with, Min_Max_Scaler is 1.445518775455971
# The Mean squared error using data with, Min_Max_Scaler is 3.878624048658679
# The Root Mean squared error using data with, Min_Max_Scaler is 1.9694222626594529
# The R2_sqaure using data with, Min_Max_Scaler is 0.6920550538694212
# ==================================================================================================================================================
# Working with: X_Standard_Scaler
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_Standard_Scaler
# Prediction started with: X_Standard_Scaler
# Prediction completed with: X_Standard_Scaler
# Calculating metrics for X_Standard_Scaler
# The Mean absolute error using data with, Standard_Scaler is 1.445518775455973
# The Mean squared error using data with, Standard_Scaler is 3.878624048658695
# The Root Mean squared error using data with, Standard_Scaler is 1.969422262659457
# The R2_sqaure using data with, Standard_Scaler is 0.6920550538694199
# ==================================================================================================================================================
# Working with: X_Robust_Scaler
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_Robust_Scaler
# Prediction started with: X_Robust_Scaler
# Prediction completed with: X_Robust_Scaler
# Calculating metrics for X_Robust_Scaler
# The Mean absolute error using data with, Robust_Scaler is 1.4455187754559695
# The Mean squared error using data with, Robust_Scaler is 3.8786240486586805
# The Root Mean squared error using data with, Robust_Scaler is 1.9694222626594533
# The R2_sqaure using data with, Robust_Scaler is 0.692055053869421
# ==================================================================================================================================================
# Working with: X_MaxAbs_Scaler
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_MaxAbs_Scaler
# Prediction started with: X_MaxAbs_Scaler
# Prediction completed with: X_MaxAbs_Scaler
# Calculating metrics for X_MaxAbs_Scaler
# The Mean absolute error using data with, MaxAbs_Scaler is 1.4455187754559722
# The Mean squared error using data with, MaxAbs_Scaler is 3.878624048658672
# The Root Mean squared error using data with, MaxAbs_Scaler is 1.969422262659451
# The R2_sqaure using data with, MaxAbs_Scaler is 0.6920550538694217
# ==================================================================================================================================================

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
def Simple_Linear_Regression():
    Linear_Regression = LinearRegression()
    param_grid = {'alpha': [0.05,0.07,0.09,0.1]}
    for key,value in X_data.items():
        print(f'Working with: {key}')
        print("--------------------------------------------------------------------------------------------------------------------------------------------------")
        ridge_reg = Ridge()
        grid_search = GridSearchCV(ridge_reg, param_grid, cv=5, scoring='neg_mean_squared_error')
        grid_search.fit(value[0],y_train)
        print(f'Done with fitting the data using: {key}')
        best_ridge_model = grid_search.best_estimator_
        print(f"Best ridge model parameter is {best_ridge_model}")
        print(f'Prediction started with: {key}')
        y_predicted = best_ridge_model.predict(value[1])
        print(f'Prediction completed with: {key}')
        print(f"Calculating metrics for {key}")
        MAE,MSE,RMSE,r2 = metrics(y_test,y_predicted)
        print(f"The Mean absolute error using data with, {key[2:]} is {MAE}")
        print(f"The Mean squared error using data with, {key[2:]} is {MSE}")
        print(f"The Root Mean squared error using data with, {key[2:]} is {RMSE}")
        print(f"The R2_sqaure using data with, {key[2:]} is {r2}")
        print("==================================================================================================================================================")
Simple_Linear_Regression()
# Out:
# Working with: X_without_scaling
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_without_scaling
# Best ridge model parameter is Ridge(alpha=0.1)
# Prediction started with: X_without_scaling
# Prediction completed with: X_without_scaling
# Calculating metrics for X_without_scaling
# The Mean absolute error using data with, without_scaling is 1.4455202768827382
# The Mean squared error using data with, without_scaling is 3.8785538299788342
# The Root Mean squared error using data with, without_scaling is 1.9694044353506555
# The R2_sqaure using data with, without_scaling is 0.6920606289102891
# ==================================================================================================================================================
# Working with: X_Min_Max_Scaler
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_Min_Max_Scaler
# Best ridge model parameter is Ridge(alpha=0.05)
# Prediction started with: X_Min_Max_Scaler
# Prediction completed with: X_Min_Max_Scaler
# Calculating metrics for X_Min_Max_Scaler
# The Mean absolute error using data with, Min_Max_Scaler is 1.4952927540283556
# The Mean squared error using data with, Min_Max_Scaler is 4.003567079818065
# The Root Mean squared error using data with, Min_Max_Scaler is 2.000891571229702
# The R2_sqaure using data with, Min_Max_Scaler is 0.6821351506983278
# ==================================================================================================================================================
# Working with: X_Standard_Scaler
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_Standard_Scaler
# Best ridge model parameter is Ridge(alpha=0.05)
# Prediction started with: X_Standard_Scaler
# Prediction completed with: X_Standard_Scaler
# Calculating metrics for X_Standard_Scaler
# The Mean absolute error using data with, Standard_Scaler is 1.4523063335934219
# The Mean squared error using data with, Standard_Scaler is 3.9047181919583402
# The Root Mean squared error using data with, Standard_Scaler is 1.9760359794189832
# The R2_sqaure using data with, Standard_Scaler is 0.6899832986665635
# ==================================================================================================================================================
# Working with: X_Robust_Scaler
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_Robust_Scaler
# Best ridge model parameter is Ridge(alpha=0.05)
# Prediction started with: X_Robust_Scaler
# Prediction completed with: X_Robust_Scaler
# Calculating metrics for X_Robust_Scaler
# The Mean absolute error using data with, Robust_Scaler is 1.4607196098205306
# The Mean squared error using data with, Robust_Scaler is 3.9274020636798674
# The Root Mean squared error using data with, Robust_Scaler is 1.9817674090770256
# The R2_sqaure using data with, Robust_Scaler is 0.6881823033734686
# ==================================================================================================================================================
# Working with: X_MaxAbs_Scaler
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_MaxAbs_Scaler
# Best ridge model parameter is Ridge(alpha=0.05)
# Prediction started with: X_MaxAbs_Scaler
# Prediction completed with: X_MaxAbs_Scaler
# Calculating metrics for X_MaxAbs_Scaler
# The Mean absolute error using data with, MaxAbs_Scaler is 1.4986966082765478
# The Mean squared error using data with, MaxAbs_Scaler is 4.009181001601056
# The Root Mean squared error using data with, MaxAbs_Scaler is 2.0022939348659716
# The R2_sqaure using data with, MaxAbs_Scaler is 0.6816894310773085
# ==================================================================================================================================================

# %%
from sklearn.svm import SVR
def SVM():
    SV_Regressor = SVR()
    for key,value in X_data.items():
        print(f'Working with: {key}')
        print("--------------------------------------------------------------------------------------------------------------------------------------------------")
        SV_Regressor.fit(value[0],y_train)
        print(f'Done with fitting the data using: {key}')
        print(f'Prediction started with: {key}')
        y_predicted = SV_Regressor.predict(value[1])
        print(f'Prediction completed with: {key}')
        print(f"Calculating metrics for {key}")
        MAE,MSE,RMSE,r2 = metrics(y_test,y_predicted)
        print(f"The Mean absolute error using data with, {key[2:]} is {MAE}")
        print(f"The Mean squared error using data with, {key[2:]} is {MSE}")
        print(f"The Root Mean squared error using data with, {key[2:]} is {RMSE}")
        print(f"The R2_sqaure using data with, {key[2:]} is {r2}")
        print("==================================================================================================================================================")
SVM()
# Out:
# Working with: X_without_scaling
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_without_scaling
# Prediction started with: X_without_scaling
# Prediction completed with: X_without_scaling
# Calculating metrics for X_without_scaling
# The Mean absolute error using data with, without_scaling is 2.62015592675494
# The Mean squared error using data with, without_scaling is 11.762002263081616
# The Root Mean squared error using data with, without_scaling is 3.4295775633569825
# The R2_sqaure using data with, without_scaling is 0.06615100926190431
# ==================================================================================================================================================
# Working with: X_Min_Max_Scaler
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_Min_Max_Scaler
# Prediction started with: X_Min_Max_Scaler
# Prediction completed with: X_Min_Max_Scaler
# Calculating metrics for X_Min_Max_Scaler
# The Mean absolute error using data with, Min_Max_Scaler is 1.237700332700643
# The Mean squared error using data with, Min_Max_Scaler is 3.7638557533847705
# The Root Mean squared error using data with, Min_Max_Scaler is 1.9400659147010368
# The R2_sqaure using data with, Min_Max_Scaler is 0.7011671297144221
# ==================================================================================================================================================
# Working with: X_Standard_Scaler
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_Standard_Scaler
# Prediction started with: X_Standard_Scaler
# Prediction completed with: X_Standard_Scaler
# Calculating metrics for X_Standard_Scaler
# The Mean absolute error using data with, Standard_Scaler is 1.2148611205368798
# The Mean squared error using data with, Standard_Scaler is 3.6137253099270135
# The Root Mean squared error using data with, Standard_Scaler is 1.9009800919333726
# The R2_sqaure using data with, Standard_Scaler is 0.7130867978088709
# ==================================================================================================================================================
# Working with: X_Robust_Scaler
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_Robust_Scaler
# Prediction started with: X_Robust_Scaler
# Prediction completed with: X_Robust_Scaler
# Calculating metrics for X_Robust_Scaler
# The Mean absolute error using data with, Robust_Scaler is 1.2319183867934649
# The Mean squared error using data with, Robust_Scaler is 3.6143085208539225
# The Root Mean squared error using data with, Robust_Scaler is 1.9011334831762663
# The R2_sqaure using data with, Robust_Scaler is 0.7130404935382799
# ==================================================================================================================================================
# Working with: X_MaxAbs_Scaler
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_MaxAbs_Scaler
# Prediction started with: X_MaxAbs_Scaler
# Prediction completed with: X_MaxAbs_Scaler
# Calculating metrics for X_MaxAbs_Scaler
# The Mean absolute error using data with, MaxAbs_Scaler is 1.2414879735291577
# The Mean squared error using data with, MaxAbs_Scaler is 3.775451548828881
# The Root Mean squared error using data with, MaxAbs_Scaler is 1.9430521220051924
# The R2_sqaure using data with, MaxAbs_Scaler is 0.7002464767822018
# ==================================================================================================================================================

# %%
pip install ensemble
# Out:
# Requirement already satisfied: ensemble in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (0.0.dev1)
# Requirement already satisfied: docopt in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from ensemble) (0.6.2)
# Requirement already satisfied: lxml in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from ensemble) (4.9.3)
# Requirement already satisfied: numpy in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from ensemble) (1.24.3)
# Requirement already satisfied: pandas in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from ensemble) (2.0.3)
# Requirement already satisfied: pyprind in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from ensemble) (2.11.3)
# Requirement already satisfied: pysut in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from ensemble) (1.1)
# Requirement already satisfied: pytest in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from ensemble) (7.4.3)
# Requirement already satisfied: stats-arrays in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from ensemble) (0.6.6)
# Requirement already satisfied: wrapt in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from ensemble) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from pandas->ensemble) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from pandas->ensemble) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from pandas->ensemble) (2023.3)
# Requirement already satisfied: scipy in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from pysut->ensemble) (1.10.1)
# Requirement already satisfied: iniconfig in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from pytest->ensemble) (2.0.0)
# Requirement already satisfied: packaging in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from pytest->ensemble) (23.2)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from pytest->ensemble) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from pytest->ensemble) (1.1.3)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from pytest->ensemble) (2.0.1)
# Requirement already satisfied: colorama in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from pytest->ensemble) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\hp\desktop\pw_projects\body_mass_index_from_face_images\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->ensemble) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
def Random_Forest_Regressor():
    Random_Forest_Regressor = RandomForestRegressor()
    for key,value in X_data.items():
        print(f'Working with: {key}')
        print("--------------------------------------------------------------------------------------------------------------------------------------------------")
        Random_Forest_Regressor.fit(value[0],y_train)
        print(f'Done with fitting the data using: {key}')
        print(f'Prediction started with: {key}')
        y_predicted = Random_Forest_Regressor.predict(value[1])
        print(f'Prediction completed with: {key}')
        print(f"Calculating metrics for {key}")
        MAE,MSE,RMSE,r2 = metrics(y_test,y_predicted)
        print(f"The Mean absolute error using data with, {key[2:]} is {MAE}")
        print(f"The Mean squared error using data with, {key[2:]} is {MSE}")
        print(f"The Root Mean squared error using data with, {key[2:]} is {RMSE}")
        print(f"The R2_sqaure using data with, {key[2:]} is {r2}")
        print("==================================================================================================================================================")
Random_Forest_Regressor()
# Out:
# Working with: X_without_scaling
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_without_scaling
# Prediction started with: X_without_scaling
# Prediction completed with: X_without_scaling
# Calculating metrics for X_without_scaling
# The Mean absolute error using data with, without_scaling is 0.8315496327097076
# The Mean squared error using data with, without_scaling is 1.9777225411938555
# The Root Mean squared error using data with, without_scaling is 1.4063152353558057
# The R2_sqaure using data with, without_scaling is 0.8429779082043823
# ==================================================================================================================================================
# Working with: X_Min_Max_Scaler
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_Min_Max_Scaler
# Prediction started with: X_Min_Max_Scaler
# Prediction completed with: X_Min_Max_Scaler
# Calculating metrics for X_Min_Max_Scaler
# The Mean absolute error using data with, Min_Max_Scaler is 0.8241861449357326
# The Mean squared error using data with, Min_Max_Scaler is 1.9594523052707913
# The Root Mean squared error using data with, Min_Max_Scaler is 1.3998043810728666
# The R2_sqaure using data with, Min_Max_Scaler is 0.844428481074178
# ==================================================================================================================================================
# Working with: X_Standard_Scaler
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_Standard_Scaler
# Prediction started with: X_Standard_Scaler
# Prediction completed with: X_Standard_Scaler
# Calculating metrics for X_Standard_Scaler
# The Mean absolute error using data with, Standard_Scaler is 0.844745826632723
# The Mean squared error using data with, Standard_Scaler is 2.0640434317014686
# The Root Mean squared error using data with, Standard_Scaler is 1.4366779150879534
# The R2_sqaure using data with, Standard_Scaler is 0.8361244257209477
# ==================================================================================================================================================
# Working with: X_Robust_Scaler
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_Robust_Scaler
# Prediction started with: X_Robust_Scaler
# Prediction completed with: X_Robust_Scaler
# Calculating metrics for X_Robust_Scaler
# The Mean absolute error using data with, Robust_Scaler is 0.8370018814346722
# The Mean squared error using data with, Robust_Scaler is 2.0234420408176557
# The Root Mean squared error using data with, Robust_Scaler is 1.422477430688324
# The R2_sqaure using data with, Robust_Scaler is 0.8393479897920431
# ==================================================================================================================================================
# Working with: X_MaxAbs_Scaler
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with fitting the data using: X_MaxAbs_Scaler
# Prediction started with: X_MaxAbs_Scaler
# Prediction completed with: X_MaxAbs_Scaler
# Calculating metrics for X_MaxAbs_Scaler
# The Mean absolute error using data with, MaxAbs_Scaler is 0.8340192074053135
# The Mean squared error using data with, MaxAbs_Scaler is 2.0548249444323927
# The Root Mean squared error using data with, MaxAbs_Scaler is 1.433466059742048
# The R2_sqaure using data with, MaxAbs_Scaler is 0.8368563312961897
# ==================================================================================================================================================

# %%
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, median_absolute_error

def metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = mean_squared_error(y_true, y_pred, squared=False)
    r2 = r2_score(y_true, y_pred)
    medae = median_absolute_error(y_true, y_pred)
    return mae, mse, rmse, r2, medae

def Random_Forest_Regressor(X_data, y_data):
    Random_Forest_Regressor = RandomForestRegressor()
    
    # Initialize KFold cross-validator
    kf = KFold(n_splits=5, shuffle=True, random_state=42)  # Adjust the number of splits as needed
    param_grid = {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 10, 20, 30],
        # Add other hyperparameters you want to tune
    }
    for train_index, test_index in kf.split(X_data):
        X_train, X_test = X_data.iloc[train_index], X_data.iloc[test_index]
        y_train, y_test = y_data.iloc[train_index], y_data.iloc[test_index]

        print("--------------------------------------------------------------------------------------------------------------------------------------------------")
        print(f'Done with splitting the data using cross-validation')

        # Robust scaling of the features to handle outliers
        scaler = RobustScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)
        
        grid_search = GridSearchCV(Random_Forest_Regressor,param_grid, cv=kf, scoring='neg_mean_absolute_error', n_jobs=-1)
        grid_search.fit(X_train_scaled, y_train)
        print(f'Done with fitting the data')

        y_predicted = grid_search.predict(X_test_scaled)
        print(f'Prediction completed')

        print(f"Calculating metrics")
        MAE, MSE, RMSE, R2, MedAE = metrics(y_test, y_predicted)

        print(f"The Mean Absolute Error is {MAE}")
        print(f"The Mean Squared Error is {MSE}")
        print(f"The Root Mean Squared Error is {RMSE}")
        print(f"The R2 Square is {R2}")
        print(f"The Median Absolute Error is {MedAE}")

        print("==================================================================================================================================================")
    print("Best Hyperparameters:", grid_search.best_params_)
    print("Best Negative Mean Absolute Error:", grid_search.best_score_)
# Example usage:
# Assuming you have X_data and y_data defined elsewhere
# Random_Forest_Regressor(X_data, y_data)

# %%
Random_Forest_Regressor(X, y)
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with splitting the data using cross-validation
# Done with fitting the data
# Prediction completed
# Calculating metrics
# The Mean Absolute Error is 0.839684504371877
# The Mean Squared Error is 2.056090431196657
# The Root Mean Squared Error is 1.4339073997984169
# The R2 Square is 0.8410357761007918
# The Median Absolute Error is 0.41002108174922114
# ==================================================================================================================================================
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with splitting the data using cross-validation
# Done with fitting the data
# Prediction completed
# Calculating metrics
# The Mean Absolute Error is 0.7138362806087422
# The Mean Squared Error is 1.2940106585535756
# The Root Mean Squared Error is 1.137545892943918
# The R2 Square is 0.8933899648927872
# The Median Absolute Error is 0.3818309537375466
# ==================================================================================================================================================
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with splitting the data using cross-validation
# Done with fitting the data
# Prediction completed
# Calculating metrics
# The Mean Absolute Error is 0.765260170644186
# The Mean Squared Error is 1.8096381263888859
# The Root Mean Squared Error is 1.345227908716172
# The R2 Square is 0.8516275191942478
# The Median Absolute Error is 0.40701787249080823
# ==================================================================================================================================================
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with splitting the data using cross-validation
# Done with fitting the data
# Prediction completed
# Calculating metrics
# The Mean Absolute Error is 0.7233128854259899
# The Mean Squared Error is 1.2528240500258356
# The Root Mean Squared Error is 1.1192962297916649
# The R2 Square is 0.8917890878332854
# The Median Absolute Error is 0.3822920513644128
# ==================================================================================================================================================
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Done with splitting the data using cross-validation
# Done with fitting the data
# Prediction completed
# Calculating metrics
# The Mean Absolute Error is 0.8029052989265182
# The Mean Squared Error is 1.7999487374891188
# The Root Mean Squared Error is 1.3416216819540145
# The R2 Square is 0.8615909661641885
# The Median Absolute Error is 0.41941716098286186
# ==================================================================================================================================================
# Best Hyperparameters: {'max_depth': 20, 'n_estimators': 100}
# Best Negative Mean Absolute Error: -0.8126140174998063
